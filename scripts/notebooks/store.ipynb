# %%
import numpy as np
import pandas as pd

# %%
x = np.array([[242, 273], [244, 286], [244, 286]])

# %%
x
# Out:
# array([[242, 273],
#        [244, 286],
#        [244, 286]])

# %%
x.shape
# Out:
# (3, 2)

# %%
y = x.reshape(*x.shape, 1)

# %%
y
# Out:
# array([[[242],
#         [273]],
#
#        [[244],
#         [286]],
#
#        [[244],
#         [286]]])

# %%
y.shape
# Out:
# (3, 2, 1)

# %%
value_name = "value"
index_names = ['point', 'component']

# %%
index = pd.MultiIndex.from_product([range(s)for s in x.shape], names=index_names)
df = pd.Series(x.flatten(), index=index, name=value_name)
df = df.reset_index()
#df.drop(columns="record_id", inplace=True)

# %%
df["image_id"] = "b12312312"

# %%
y.reshape(3, 2)
# Out:
# array([[242, 273],
#        [244, 286],
#        [244, 286]])

# %%
df
# Out:
#    point  component  value   image_id
# 0      0          0    242  b12312312
# 1      0          1    273  b12312312
# 2      1          0    244  b12312312
# 3      1          1    286  b12312312
# 4      2          0    244  b12312312
# 5      2          1    286  b12312312

# %%
pd.DataFrame(y, columns=["landmark_index", "landmark_coord", "landmark_value"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-921af8732e81> in <module>()
# ----> 1 pd.DataFrame(y, columns=["landmark_index", "landmark_coord", "landmark_value"])
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     359             else:
#     360                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 361                                          copy=copy)
#     362         elif isinstance(data, (list, types.GeneratorType)):
#     363             if isinstance(data, types.GeneratorType):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     511         # by definition an array here
#     512         # the dtypes will be coerced to a single dtype
# ...

# %%
from thickshake.storage import Store

# %%
store = Store()

# %%
store.get_dataframe("/faces/embeddings")
# Out:
#      point  component     value    image_id box_number
# 0        0          0 -0.017502  b3015271_5          0
# 1        0          1  0.042054  b3015271_5          0
# 2        0          2  0.011916  b3015271_5          0
# 3        0          3  0.080320  b3015271_5          0
# 4        0          4 -0.131815  b3015271_5          0
# 5        0          5  0.031043  b3015271_5          0
# 6        0          6 -0.016294  b3015271_5          0
# 7        0          7 -0.067521  b3015271_5          0
# 8        0          8  0.055354  b3015271_5          0
# 9        0          9 -0.055125  b3015271_5          0
# 10       0         10  0.199958  b3015271_5          0
# 11       0         11 -0.033941  b3015271_5          0
# 12       0         12 -0.198232  b3015271_5          0
# 13       0         13 -0.073535  b3015271_5          0
# 14       0         14 -0.044827  b3015271_5          0
# 15       0         15  0.124208  b3015271_5          0
# ...
